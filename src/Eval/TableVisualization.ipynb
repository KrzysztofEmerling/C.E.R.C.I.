# %%
import numpy as np
import matplotlib.pyplot as plt

# ===== DANE =====
opening_table = np.array([
    [0, 0, 0, 0, 0, 0, 0, 0,
     50, 50, 25, 20, 20, 25, 50, 50,
     10, 10, 20, 30, 30, 20, 10, 10,
     5, 5, 10, 20, 20, 10, 5, 5,
     0, 0, 10, 25, 25, 10, 0, 0,
     5, 5, 5, 20, 20, 5, 5, 5,
     10, 10, 10, 10, 10, 10, 10, 10,
     0, 0, 0, 0, 0, 0, 0, 0],

    [-50, -40, -30, -30, -30, -30, -40, -50,
     -40, -20, 0, 0, 0, 0, -20, -40,
     -30, 0, 10, 15, 15, 10, 0, -30,
     -30, 5, 15, 20, 20, 15, 5, -30,
     -30, 0, 15, 20, 20, 15, 0, -30,
     -30, 5, 10, 15, 15, 10, 5, -30,
     -40, -20, 0, 5, 5, 0, -20, -40,
     -50, -40, -30, -30, -30, -30, -40, -50],

    [-20, -10, -10, -10, -10, -10, -10, -20,
     -10, 5, 0, 0, 0, 0, 5, -10,
     -10, 10, 10, 10, 10, 10, 10, -10,
     -10, 0, 10, 10, 10, 10, 0, -10,
     -10, 5, 5, 10, 10, 5, 5, -10,
     -10, 0, 5, 10, 10, 5, 0, -10,
     -10, 0, 0, 0, 0, 0, 0, -10,
     -20, -10, -10, -10, -10, -10, -10, -20],

    [2, 0, 0, 5, 5, 5, 0, 2,
     -5, -10, -10, 0, 0, 0, -10, -5,
     -5, 0, 0, 0, 0, 0, 0, -5,
     -5, 0, 0, 0, 0, 0, 0, -5,
     -5, 0, 0, 0, 0, 0, 0, -5,
     -5, 0, 0, 0, 0, 0, 0, -5,
     -5, 0, 0, 0, 0, 0, 0, -5,
     0, 0, 0, 5, 5, 0, 0, 0],

    [-20, -10, -10, -5, -5, -10, -10, -20,
     -10, 0, 0, 0, 0, 0, 0, -10,
     -10, 0, 5, 5, 5, 5, 0, -10,
     -5, 0, 5, 5, 5, 5, 0, -5,
     -5, 0, 5, 5, 5, 5, 0, 0,
     -10, 0, 5, 5, 5, 5, 5, -10,
     -10, 0, 0, 0, 0, 5, 0, -10,
     -20, -10, -10, -5, -5, -10, -10, -20],

    [5, 10, 10, -5, 0, -5, 10, 10,
     -10, -10, -10, -10, -10, -10, -10, -10,
     -10, -10, -20, -20, -20, -20, -20, -20,
     -20, -30, -30, -40, -40, -30, -30, -20,
     -30, -40, -40, -50, -50, -40, -40, -30,
     -30, -40, -40, -50, -50, -40, -40, -30,
     -30, -40, -40, -50, -50, -40, -40, -30,
     -30, -40, -40, -50, -50, -40, -40, -30]
], dtype=float).reshape(6, 8, 8)

files = list("ABCDEFGH")
ranks = list(range(1, 9))
pieces = ["Pionów", "Skoczków", "Gońców", "Wierz", "Hetmanów", "Króla"]
for i in range(6):
    fig, ax = plt.subplots(figsize=(8, 8))

    im = ax.imshow(opening_table[i], origin="lower", cmap="viridis", vmin=-50, vmax=50)
    ax.set_xticks(range(8))
    ax.set_yticks(range(8))
    ax.set_xticklabels(files, fontsize=16)
    ax.set_yticklabels(ranks, fontsize=16)

    # wartości w komórkach
    for y in range(8):
        for x in range(8):
            ax.text(
                x, y,
                f"{int(opening_table[i, y, x])}",
                ha="center",
                va="center",
                fontsize=20,
                color="black"
            )

    cbar = plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    cbar.ax.tick_params(labelsize=16)
    # ax.set_title(f"Heatmapa Tabel Aktywności {pieces[i]} w Otwarciu")
    ax.set_aspect("equal")

    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# ===== DANE =====
opening_table = np.array([
    [0, 0, 0, 0, 0, 0, 0, 0,
     10, 10, 10, 0, 0, 0, 10, 10,
     10, 10, 10, 10, 10, 10, 10, 10,
     20, 20, 20, 20, 20, 20, 20, 20,
     30, 30, 30, 30, 30, 30, 30, 30,
     40, 40, 40, 40, 40, 40, 40, 40,
     50, 50, 50, 50, 50, 50, 50, 50,
     0, 0, 0, 0, 0, 0, 0, 0],

    [-50, -40, -30, -30, -30, -30, -40, -50,
     -40, -20, 0, 0, 0, 0, -20, -40,
     -30, 0, 10, 15, 15, 10, 0, -30,
     -30, 5, 15, 20, 20, 15, 5, -30,
     -30, 0, 15, 20, 20, 15, 0, -30,
     -30, 5, 10, 15, 15, 10, 5, -30,
     -40, -20, 0, 5, 5, 0, -20, -40,
     -50, -40, -30, -30, -30, -30, -40, -50],

    [-20, -10, -10, -10, -10, -10, -10, -20,
     -10, 5, 0, 0, 0, 0, 5, -10,
     -10, 10, 10, 10, 10, 10, 10, -10,
     -10, 0, 10, 10, 10, 10, 0, -10,
     -10, 5, 5, 10, 10, 5, 5, -10,
     -10, 0, 5, 10, 10, 5, 0, -10,
     -10, 0, 0, 0, 0, 0, 0, -10,
     -20, -10, -10, -10, -10, -10, -10, -20],

    [-10, 2, 2, 2, 2, 2, 2, -10,
     -5, 2, 2, 2, 2, 2, 2, -5,
     -5, 1, 1, 1, 1, 1, 1, -5,
     -5, 0, 0, 0, 0, 0, 0, -5,
     -5, 0, 0, 0, 0, 0, 0, -5,
     -5, 0, 0, 0, 0, 0, 0, -5,
     -5, 0, 0, 0, 0, 0, 0, -5,
     -15, -5, -5, -5, -5, -5, -5, -15],

    [-20, -10, -10, -5, -5, -10, -10, -20,
     -10, 0, 0, 0, 0, 0, 0, -10,
     -10, 0, 5, 5, 5, 5, 0, -10,
     -5, 0, 5, 5, 5, 5, 0, -5,
     -5, 0, 5, 5, 5, 5, 0, 0,
     -10, 0, 5, 5, 5, 5, 5, -10,
     -10, 0, 0, 0, 0, 5, 0, -10,
     -20, -10, -10, -5, -5, -10, -10, -20],

    [-50, -40, -30, -20, -20, -30, -40, -50,
     -30, -20, -10, 0, 0, -10, -20, -30,
     -30, -10, 20, 30, 30, 20, -10, -30,
     -30, -10, 30, 40, 40, 30, -10, -30,
     -30, -10, 30, 40, 40, 30, -10, -30,
     -30, -10, 20, 30, 30, 20, -10, -30,
     -30, -30, 0, 0, 0, 0, -30, -30,
     -50, -30, -30, -30, -30, -30, -30, -50]
], dtype=float).reshape(6, 8, 8)

files = list("ABCDEFGH")
ranks = list(range(1, 9))
pieces = ["Pionów", "Skoczków", "Gońców", "Wierz", "Hetmanów", "Króla"]
for i in range(6):
    fig, ax = plt.subplots(figsize=(8, 8))

    im = ax.imshow(opening_table[i], origin="lower", cmap="viridis", vmin=-50, vmax=50)
    ax.set_xticks(range(8))
    ax.set_yticks(range(8))
    ax.set_xticklabels(files, fontsize=16)
    ax.set_yticklabels(ranks, fontsize=16)

    # wartości w komórkach
    for y in range(8):
        for x in range(8):
            ax.text(
                x, y,
                f"{int(opening_table[i, y, x])}",
                ha="center",
                va="center",
                fontsize=20,
                color="black"
            )

    cbar = plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    cbar.ax.tick_params(labelsize=16)
    # ax.set_title(f"Heatmapa Tabel Aktywności {pieces[i]} w Końcówce")
    ax.set_aspect("equal")

    plt.tight_layout()
    plt.show()
